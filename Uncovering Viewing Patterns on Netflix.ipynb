# %%
# !pip install pandas numpy matplotlib seaborn --quiet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for visualizations
sns.set(style="whitegrid")
print("✅ Environment ready!")
# Out:
# ✅ Environment ready!

# %% [markdown]
# ## Problem Statement:
#
# Netflix has a vast catalog of content. But what makes content popular? Are there directors or genres that dominate? What ratings are common? This project uses EDA to analyze Netflix’s content and extract insights for platform strategy, viewer preferences, and content acquisition.

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#Checking for nulls
df.isnull().sum()
#Converting date formats

#Removing duplicates
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df['country'] = df['country'].fillna('unknown')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                                NaN        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df['director'] = df['director'].fillna('unknown director')
df.head()
# Out:
#   show_id     type                  title          director  \
# 0      s1    Movie   Dick Johnson Is Dead   Kirsten Johnson
# 1      s2  TV Show          Blood & Water  unknown director
# 2      s3  TV Show              Ganglands   Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  unknown director
# 4      s5  TV Show           Kota Factory  unknown director
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                                NaN        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df['cast'] = df['cast'].fillna('unknown cast')
df.head()
# Out:
#   show_id     type                  title          director  \
# 0      s1    Movie   Dick Johnson Is Dead   Kirsten Johnson
# 1      s2  TV Show          Blood & Water  unknown director
# 2      s3  TV Show              Ganglands   Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  unknown director
# 4      s5  TV Show           Kota Factory  unknown director
#
#                                                 cast        country  \
# 0                                       unknown cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                       unknown cast        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df = df.dropna(subset=['date_added', 'rating', 'duration'])
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.drop_duplicates(inplace =True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8790 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   cast          8790 non-null   object
#  5   country       8790 non-null   object
#  6   date_added    8790 non-null   datetime64[ns]
#  7   release_year  8790 non-null   int64
#  8   rating        8790 non-null   object
#  9   duration      8790 non-null   object
#  10  listed_in     8790 non-null   object
#  11  description   8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 892.7+ KB

# %%
df['title'] = df['title'].str.strip()
df['director'] = df['director'].str.strip()
df['cast'] = df['cast'].str.strip()
df['listed_in'] = df['listed_in'].str.strip()
df.head(5)
# Out:
#   show_id     type                  title          director  \
# 0      s1    Movie   Dick Johnson Is Dead   Kirsten Johnson
# 1      s2  TV Show          Blood & Water  unknown director
# 2      s3  TV Show              Ganglands   Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  unknown director
# 4      s5  TV Show           Kota Factory  unknown director
#
#                                                 cast        country  \
# 0                                       unknown cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                       unknown cast        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ## EDA

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Content Breakdown
plt.figure(figsize=(6,4)) #size of the chart
sns.countplot(data=df, x='type',palette ='Set2') #chart type and color

plt.title('distribution of movies and TV shows on Netflix')
plt.xlabel('Type')
plt.ylabel('count')
plt.show()

# %%
#calculate the % of movies and tv show

Total = df['type'].value_counts().sum()
movie_percentage =(df['type'].value_counts()['Movie']/Total)*100
TVshow_percentage =(df['type'].value_counts()['TV Show']/Total)*100

#string literal we use f"typw:{variable:2f}%"
print(f"Movies: {movie_percentage:.2f}%")
print(f"Tv shows: {TVshow_percentage:.2f}%")
# Out:
# Movies: 69.69%
# Tv shows: 30.31%

# %%
# Top Directors
Top_directors = df['director'].value_counts().head(5)
print(Top_directors)
# Out:
# unknown director          2621
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Name: director, dtype: int64

# %%
#top director with highest rating films or tv 
Top_directors_withRating = df.groupby('director').agg(
    num_titles =('title', 'count'),
    highest_rating=('rating','max')
).sort_values(by='num_titles', ascending=False).head(10)
print(Top_directors_withRating)
# Out:
#                         num_titles highest_rating
# director
# unknown director              2621       TV-Y7-FV
# Rajiv Chilaka                   19          TV-Y7
# Raúl Campos, Jan Suter          18          TV-MA
# Suhas Kadav                     16       TV-Y7-FV
# Marcus Raboy                    16          TV-MA
# Jay Karas                       14          TV-MA
# Cathy Garcia-Molina             13          TV-PG
# Youssef Chahine                 12          TV-MA
# Jay Chapman                     12          TV-MA
# Martin Scorsese                 12          TV-MA

# %% [markdown]
# ## Genre Analysis (EDA on listed_in column)

# %%
# Split the genre string and explode
df['genre'] = df['listed_in'].str.split(', ')
df_exploded = df.explode('genre')

# Top 10 genres
top_genres = df_exploded['genre'].value_counts().head(10)
print(top_genres)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=top_genres.values, y=top_genres.index, palette='Set3')
plt.title('Top 10 Most Common Netflix Genres')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.show()
# Out:
# International Movies        2752
# Dramas                      2426
# Comedies                    1674
# International TV Shows      1349
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    762
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: genre, dtype: int64

# %% [markdown]
# ##  Content Rating Trends Over Time

# %%
rating_year = df.groupby(['release_year', 'rating']).size().reset_index(name='count')

plt.figure(figsize=(12,6))
sns.lineplot(data=rating_year, x='release_year', y='count', hue='rating')
plt.title('Content Ratings Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.legend(title='Rating')
plt.show()

# %% [markdown]
# ## Country analysis
#
# Insight : The .explode() function is used when a single column contains lists (or arrays), and you want to turn each element of those lists into a separate row—while keeping the other column values the same.

# %%
# Split and explode countries
df['country_split'] = df['country'].str.split(', ')
df_country = df.explode('country_split')

# Top countries
top_countries = df_country['country_split'].value_counts().head(10)
print(top_countries)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title('Top 10 Countries Producing Netflix Content')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()
# Out:
# United States     3680
# India             1046
# unknown            829
# United Kingdom     803
# Canada             445
# France             393
# Japan              316
# Spain              232
# South Korea        231
# Germany            226
# Name: country_split, dtype: int64

# %%
# Mapping TV ratings to numeric values
rating_map = {
    'TV-Y': 0,
    'TV-Y7': 1,
    'TV-G': 2,
    'TV-PG': 3,
    'TV-14': 4,
    'TV-MA': 5,
    'NR': 0  # 'NR' (Not Rated) can be treated as 0 or omitted
}

# Replace the TV ratings with numeric values
df['rating_numeric'] = df['rating'].map(rating_map)

# Check for any 'NaN' values that couldn't be mapped and handle them
df['rating_numeric'] = df['rating_numeric'].fillna(0)  # Fill missing ratings with 0 or any other default value

# Verify
print(df[['rating', 'rating_numeric']].head())
# Out:
#   rating  rating_numeric
# 0  PG-13             0.0
# 1  TV-MA             5.0
# 2  TV-MA             5.0
# 3  TV-MA             5.0
# 4  TV-MA             5.0

# %%
# Convert duration to numeric for Movies
df['duration_numeric'] = df['duration'].str.extract('(\d+)').astype(float)

# Only for Movies
df_corr = df[df['type'] == 'Movie'][['rating_numeric', 'release_year', 'duration_numeric']]
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap (Movies)')
plt.show()

# %% [markdown]
# ## Analysis
#
# 📊 Interpreting the Heatmap:
# 1. rating_numeric vs release_year → 0.22
# ✅ Weak positive correlation
# As years progress, content tends to get slightly higher (more mature) ratings. But it’s not a strong relationship.
#
# 2. rating_numeric vs duration_numeric → 0.016
# ⚪ No meaningful correlation
# Movie rating has almost no relation to how long the movie is.
#
# 3. release_year vs duration_numeric → ~0 or slightly negative
# 🔴 Again, very weak or no correlation
# The release year doesn’t affect movie length significantly.

# %% [markdown]
# ##  Story telling through dataset

# %%
# Group by year and count
df['year_added'] = df['date_added'].dt.year
content_by_year = df['year_added'].value_counts().sort_index()

plt.figure(figsize=(12,6))
sns.lineplot(x=content_by_year.index, y=content_by_year.values, marker='o')
plt.title("Netflix Content Added Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Titles Added")
plt.grid(True)
plt.show()

# %%
# Extract year and month
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

# Group and count by year and month
content_added = df.groupby(['year_added', 'month_added']).size().reset_index(name='content_count')

# Sort by most content added
content_added = content_added.sort_values('content_count', ascending=False)

# Display the top 10 months
print(content_added.head(10))
# Out:
#      year_added  month_added  content_count
# 105        2021            7            257
# 85         2019           11            255
# 86         2019           12            215
# 104        2021            6            207
# 87         2020            1            205
# 84         2019           10            193
# 72         2018           10            191
# 102        2021            4            188
# 74         2018           12            185
# 107        2021            9            183

# %%
# Create a Year-Month column for better labeling
df['year_month'] = df['date_added'].dt.to_period('M')

# Count shows added per month
monthly_counts = df['year_month'].value_counts().sort_index()

# Plot
plt.figure(figsize=(15,5))
monthly_counts.plot(kind='bar')
plt.title('Netflix Content Added Per Month')
plt.xlabel('Month-Year')
plt.ylabel('Number of Titles Added')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Export dataset

# %%
df.to_csv("netflix_cleaneddata.csv", index =False)
